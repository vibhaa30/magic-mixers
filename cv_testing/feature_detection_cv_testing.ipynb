# %%
exec(open("evaluate_gesture_colab.py").read())
# Out:
# ...
#   Hand Gesture CV Model Evaluation — Model A vs Model B
# ...
#
# File    : hand_landmarks_data.csv
# Format  : hagrid
# Samples : 25675 (before filtering)
#
# Dropped 15940 irrelevant samples (stop, palm, call, rock, etc.)
# Kept    9735 samples
#
# Class distribution after filtering:
#   class 0 [fist(0)]: 945 samples
#   class 1 [one(1)]: 1263 samples
#   class 2 [two(2)]: 2784 samples
#   class 3 [three(3)]: 3109 samples
#   class 4 [four(4)]: 1634 samples
#
# ...
#   MODEL A (detect_up_test.py) — 3-class scope
# ...
#
#                 precision    recall  f1-score   support
#
# other/fist (0)       0.99      0.71      0.83      5688
#    pointer (1)       0.99      0.99      0.99      1263
#      duces (2)       0.62      0.99      0.76      2784
#
#       accuracy                           0.83      9735
#      macro avg       0.87      0.90      0.86      9735
#   weighted avg       0.89      0.83      0.83      9735
#
# Macro averages:  Precision=0.8690  Recall=0.8959  F1=0.8610
#
# ...
